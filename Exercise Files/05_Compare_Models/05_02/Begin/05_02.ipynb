# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('../../../data/X_train.csv')
X_test = pd.read_csv('../../../data/X_test.csv')
y_train = pd.read_csv('../../../data/y_train.csv')
y_test = pd.read_csv('../../../data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0  ['sign', 'maturity', 'start', 'saying', 'big',...
# 1  ['mm', 'entirely', 'sure', 'understood', 'text...
# 2  ['cant', 'keep', 'talking', 'people', 'sure', ...
# 3  ['sorry', 'roommates', 'took', 'forever', 'ok'...
# 4  ['escape', 'theatre', 'going', 'watch', 'kaval...

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'sign': 6531,
#  'maturity': 4682,
#  'start': 6841,
#  'saying': 6299,
#  'big': 1411,
#  'things': 7250,
#  'actually': 874,
#  'understanding': 7565,
#  'small': 6619,
#  'nice': 5081,
#  'evening': 2824,
#  'bslvyl': 1617,
#  'mm': 4842,
#  'entirely': 2782,
#  'sure': 7026,
#  'understood': 7566,
#  'text': 7188,
#  'hey': 3621,
#  'ho': 3668,
#  'weekend': 7871,
#  'cant': 1739,
#  'keep': 4155,
#  'talking': 7098,
#  'people': 5492,
#  'pay': 5467,
#  'agree': 939,
#  'price': 5768,
#  'pls': 5612,
#  'tell': 7155,
#  'want': 7807,
#  'really': 5974,
#  'buy': 1661,
#  'much': 4948,
#  'willing': 7959,
#  'sorry': 6711,
#  'roommates': 6196,
#  'took': 7389,
#  'forever': 3116,
#  'ok': 5267,
#  'come': 2018,
#  'escape': 2802,
#  'theatre': 7223,
#  'going': 3357,
#  'watch': 7828,
#  'kavalan': 4150,
#  'minutes': 4809,
#  'didnt': 2454,
#  'get': 3297,
#  'anything': 1070,
#  'da': 2268,
#  '88066': 765,
#  'lost': 4498,
#  '12': 287,
#  'help': 3595,
#  'let': 4368,
#  'know': 4225,
#  'youve': 8220,
#  'got': 3391,
#  'money': 4881,
#  'carlos': 1766,
#  'make': 4619,
#  'call': 1691,
#  'yeah': 8162,
#  'thats': 7217,
#  'impression': 3860,
#  'havent': 3551,
#  'topic': 7398,
#  'yet': 8191,
#  'rite': 6172,
#  'petey': 5524,
#  'boy': 1547,
#  'whereare': 7927,
#  'friendsare': 3185,
#  'thekingshead': 7224,
#  'canlove': 1735,
#  'nic': 5080,
#  'esplanade': 2805,
#  'fr': 3147,
#  'home': 3685,
#  'ur': 7621,
#  'cashbalance': 1780,
#  'currently': 2246,
#  '500': 594,
#  'pounds': 5701,
#  'maximize': 4685,
#  'cashin': 1783,
#  'send': 6382,
#  'go': 3339,
#  '86688': 752,
#  '150pmeg': 323,
#  'cc': 1800,
#  '08718720201': 137,
#  'hgsuite3422lands': 3623,
#  'roww1j6hl': 6207,
#  'ill': 3837,
#  'later': 4309,
#  'chance': 1829,
#  'win': 7961,
#  '250': 413,
#  'cash': 1779,
#  'every': 2829,
#  'wk': 7994,
#  'txt': 7515,
#  'action': 867,
#  '80608': 706,
#  'tscs': 7480,
#  'wwwmovietriviatv': 8101,
#  'custcare': 2250,
#  '08712405022': 105,
#  '1x150pwk': 382,
#  'sac': 6244,
#  'score': 6316,
#  'hundredhe': 3775,
#  'set': 6410,
#  'batsman': 1317,
#  'shower': 6505,
#  'baby': 1254,
#  'dear': 2338,
#  'voucher': 7753,
#  'holder': 3676,
#  'claim': 1936,
#  'weeks': 7874,
#  'offer': 5240,
#  'pc': 5476,
#  'please': 5605,
#  'httpwwwetlpcoukexpressoffer': 3757,
#  'apply': 1093,
#  'stop': 6892,
#  'texts': 7199,
#  '80062': 697,
#  'haha': 3490,
#  'awesome': 1235,
#  'ive': 4010,
#  '4u': 588,
#  'couple': 2158,
#  'times': 7311,
#  'alls': 990,
#  'coming': 2025,
#  'ranjith': 5936,
#  'cal': 1685,
#  'drpd': 2626,
#  'deeraj': 2367,
#  'deepak': 2365,
#  '5min': 618,
#  'hold': 3675,
#  'wanna': 7805,
#  'movie': 4919,
#  'wow': 8059,
#  'youre': 8214,
#  'right': 6153,
#  'mean': 4698,
#  'guess': 3463,
#  'gave': 3262,
#  'boston': 1519,
#  'men': 4739,
#  'changed': 1832,
#  'search': 6338,
#  'location': 4454,
#  'nyc': 5212,
#  'something': 6685,
#  'cuz': 2264,
#  'signin': 6534,
#  'page': 5395,
#  'still': 6880,
#  'says': 6300,
#  'thank': 7203,
#  'god': 3347,
#  'bed': 1354,
#  'good': 3370,
#  'afternon': 921,
#  'love': 4514,
#  'today': 7348,
#  'hope': 3705,
#  'maybe': 4690,
#  'interviews': 3941,
#  'wake': 7784,
#  'miss': 4819,
#  'babe': 1250,
#  'passionate': 5452,
#  'kiss': 4198,
#  'across': 862,
#  'sea': 6337,
#  'wats': 7838,
#  'opinion': 5319,
#  'abt': 831,
#  'character': 1839,
#  'hii': 3635,
#  'ltdecimalgt': 4541,
#  'lakhs': 4277,
#  'hmmmkbut': 3662,
#  'change': 1831,
#  'field': 2993,
#  'quickly': 5896,
#  'dai': 2280,
#  'system': 7073,
#  'administrator': 890,
#  'network': 5062,
#  'dude': 2641,
#  'knw': 4231,
#  'also': 1001,
#  'teluguthts': 7161,
#  'gudk': 3459,
#  'gud': 3458,
#  'nyt': 5215,
#  'actual': 873,
#  'exam': 2852,
#  'harder': 3534,
#  'nbme': 5028,
#  'lol': 4469,
#  'mad': 4593,
#  'first': 3043,
#  'woke': 8009,
#  'remains': 6052,
#  'bro': 1597,
#  'amongst': 1018,
#  'bros': 1603,
#  'okey': 5271,
#  'doke': 2556,
#  'im': 3840,
#  'dressed': 2609,
#  'cos': 2139,
#  'laying': 4324,
#  'around': 1134,
#  'speak': 6746,
#  'bout': 1527,
#  'stuff': 6939,
#  'even': 2823,
#  'dont': 2566,
#  'trouble': 7461,
#  'convincingjust': 2118,
#  'tel': 7152,
#  'twice': 7509,
#  'neglect': 5051,
#  'msgs': 4933,
#  'read': 5960,
#  'itjust': 3993,
#  'reply': 6083,
#  'chat': 1851,
#  'regular': 6038,
#  'unless': 7587,
#  'see': 6355,
#  'person': 5512,
#  'st': 6819,
#  'andre': 1036,
#  'virgils': 7726,
#  'cream': 2189,
#  'totes': 7414,
#  'ya': 8148,
#  'taking': 7091,
#  'ure': 7622,
#  'practical': 5716,
#  'lessons': 4367,
#  'june': 4112,
#  'welcome': 7886,
#  'ukmobiledate': 7542,
#  'msg': 4929,
#  'free': 3159,
#  'giving': 3325,
#  'calling': 1711,
#  '08719839835': 160,
#  'future': 3228,
#  'mgs': 4775,
#  'billed': 1415,
#  '150p': 318,
#  'daily': 2281,
#  'cancel': 1730,
#  '89123': 779,
#  'aiyah': 960,
#  'lor': 4489,
#  'tv': 7503,
#  'forgot': 3123,
#  'check': 1860,
#  'phone': 5540,
#  'late': 4304,
#  'father': 2952,
#  'power': 5704,
#  'frndship': 3192,
#  'new': 5068,
#  'theory': 7231,
#  'argument': 1122,
#  'wins': 7974,
#  'situation': 6571,
#  'loses': 4495,
#  'argue': 1120,
#  'friends': 3184,
#  'kick': 4175,
#  'amp': 1021,
#  'say': 6297,
#  'always': 1006,
#  'correct': 2133,
#  'oh': 5261,
#  'outside': 5369,
#  'players': 5598,
#  'allowed': 988,
#  'play': 5595,
#  'made': 4596,
#  'day': 2315,
#  'great': 3425,
#  'pick': 5552,
#  'fone': 3104,
#  'dumb': 2647,
#  'together': 7357,
#  'jason': 4037,
#  'need': 5041,
#  'lunch': 4557,
#  'eat': 2679,
#  'maggi': 4604,
#  'mee': 4713,
#  'meet': 4714,
#  'lobby': 4452,
#  'sister': 6563,
#  'cleared': 1952,
#  'two': 7514,
#  'round': 6202,
#  'birla': 1426,
#  'soft': 6667,
#  'yesterday': 8190,
#  'yo': 8199,
#  'howz': 3744,
#  'girls': 3319,
#  'never': 5066,
#  'rang': 5934,
#  'india': 3885,
#  'might': 4782,
#  'kerala': 4162,
#  'daysso': 2322,
#  'prepared': 5748,
#  'take': 7088,
#  'leave': 4342,
#  'finalise': 3017,
#  'plan': 5587,
#  'travel': 7443,
#  'visitneed': 7733,
#  'finish': 3029,
#  'urgent': 7623,
#  'works': 8038,
#  'aight': 953,
#  'back': 1259,
#  'time': 7308,
#  'thinkin': 7253,
#  'goin': 3355,
#  'forwarded': 3138,
#  '448712404000please': 554,
#  '08712404000': 103,
#  'immediately': 3849,
#  'message': 4757,
#  'waiting': 7781,
#  'hi': 3626,
#  'said': 6257,
#  'would': 8056,
#  'hasnt': 3541,
#  'seen': 6362,
#  'gently': 3290,
#  'one': 5290,
#  'interested': 3933,
#  'may': 4688,
#  'business': 1654,
#  'hmm': 3658,
#  'well': 7888,
#  'night': 5090,
#  'man': 4628,
#  'accidentally': 845,
#  'left': 4348,
#  'silent': 6537,
#  'last': 4301,
#  'til': 7305,
#  'princess': 5775,
#  'thinking': 7254,
#  'asked': 1161,
#  'sen': 6381,
#  'chennai': 1875,
#  'job': 4072,
#  'hhahhaahahah': 3625,
#  'rofl': 6186,
#  'wtf': 8080,
#  'nig': 5087,
#  'leonardo': 4362,
#  'room': 6194,
#  'flatter': 3061,
#  'mine': 4797,
#  'pints': 5572,
#  'carlin': 1765,
#  'ten': 7166,
#  'date': 2305,
#  'sunday': 7001,
#  'garbage': 3254,
#  'bags': 1267,
#  'eggs': 2707,
#  'jam': 4026,
#  'bread': 1566,
#  'hannaford': 3520,
#  'wheat': 7919,
#  'chex': 1881,
#  'brand': 1560,
#  'mobile': 4855,
#  'music': 4972,
#  'service': 6406,
#  'live': 4435,
#  'player': 5597,
#  'arrive': 1140,
#  'shortly': 6493,
#  'install': 3921,
#  'browse': 1612,
#  'content': 2100,
#  'top': 7397,
#  'artists': 1145,
#  'swoop': 7063,
#  'picking': 5554,
#  'wherever': 7929,
#  'birds': 1425,
#  'meeting': 4717,
#  'shore': 6487,
#  'takin': 7090,
#  'bus': 1650,
#  'chosen': 1920,
#  'receive': 5991,
#  '350': 497,
#  'award': 1232,
#  'number': 5199,
#  '09066364311': 233,
#  'collect': 2005,
#  'selected': 6368,
#  'valued': 7671,
#  'customer': 2253,
#  'langport': 4288,
#  'probably': 5789,
#  '9pm': 806,
#  'sucks': 6974,
#  'xmas': 8134,
#  'go2sri': 3341,
#  'lanka': 4289,
#  'thk': 7260,
#  'gotta': 3396,
#  'urself': 7631,
#  'shopping': 6483,
#  'frens': 3172,
#  'present': 5753,
#  'lemme': 4357,
#  'talk': 7094,
#  'others': 5354,
#  'early': 2667,
#  'tomorrow': 7374,
#  'video': 7705,
#  'camera': 1723,
#  'phones': 5543,
#  'half': 3499,
#  'line': 4409,
#  'rental': 6070,
#  'mths': 4945,
#  'cross': 2208,
#  'ntwk': 5194,
#  'mins': 4803,
#  '100': 258,
#  'txts': 7523,
#  'mobileupd8': 4859,
#  '08001950382': 51,
#  'call2optout674': 1694,
#  '08715205273': 124,
#  'completed': 2047,
#  'degree': 2374,
#  'use': 7636,
#  'joining': 4080,
#  'finance': 3019,
#  'lasagna': 4300,
#  'vodka': 7744,
#  'west': 7905,
#  'coast': 1985,
#  'haiz': 3498,
#  'ìïll': 8255,
#  'crazy': 2187,
#  'ar': 1109,
#  'hes': 3616,
#  'married': 4656,
#  'ìï': 8254,
#  'like': 4395,
#  'gd': 3273,
#  'looking': 4483,
#  'guys': 3476,
#  'korean': 4238,
#  'leonas': 4363,
#  'fave': 2959,
#  'dun': 2649,
#  'aft': 920,
#  'mayb': 4689,
#  'prob': 5788,
#  'sparkling': 6744,
#  'breaks': 1573,
#  '45': 556,
#  'per': 5494,
#  '0121': 2,
#  '2025050': 392,
#  'visit': 7731,
#  'wwwshortbreaksorguk': 8107,
#  'yes': 8175,
#  'look': 4479,
#  'hugging': 3768,
#  'missed': 4821,
#  'alert': 974,
#  'numbers': 5201,
#  'called': 1705,
#  '07008009200': 20,
#  'uncle': 7556,
#  'touch': 7415,
#  'mum': 4958,
#  'sent': 6393,
#  'many': 4643,
#  'messages': 4763,
#  'since': 6546,
#  'getting': 3304,
#  'enjoy': 2767,
#  'rest': 6117,
#  'belive': 1375,
#  'apps': 1102,
#  'class': 1944,
#  'varaya': 7675,
#  'elaya': 2723,
#  'himthen': 3640,
#  'choose': 1916,
#  'hello': 3588,
#  'hun': 3774,
#  'ru': 6220,
#  'way': 7841,
#  'dates': 2307,
#  'guy': 3475,
#  'met': 4771,
#  'walkabout': 7789,
#  'far': 2941,
#  'soon': 6703,
#  'hows': 3742,
#  'everyone': 2834,
#  'else': 2732,
#  'long': 4475,
#  'omw': 5287,
#  'except': 2855,
#  'theres': 7237,
#  'chick': 1887,
#  'huge': 3767,
#  'boobs': 1500,
#  'asleep': 1165,
#  'neva': 5065,
#  'noe': 5123,
#  'wat': 7827,
#  'laugh': 4314,
#  'try': 7474,
#  'chitchat': 1911,
#  'logon': 4464,
#  'txting': 7520,
#  'word': 8026,
#  '8883': 771,
#  'cm': 1977,
#  'po': 5622,
#  'box': 1531,
#  '4217': 544,
#  'london': 4472,
#  'w1a': 7765,
#  '6zf': 665,
#  '16': 348,
#  '118pmsg': 285,
#  'rcvd': 5953,
#  'ask': 1159,
#  'already': 995,
#  'yar': 8154,
#  'sorts': 6718,
#  'funny': 3225,
#  'pdatenow': 5477,
#  'double': 2580,
#  '1000': 259,
#  'orange': 5332,
#  'tariffs': 7108,
#  'latest': 4311,
#  'motorola': 4913,
#  'sonyericsson': 6701,
#  'nokia': 5131,
#  'bluetooth': 1478,
#  '08000839402': 48,
#  'call2optoutyhl': 1699,
#  'natalie': 5014,
#  '20f': 393,
#  'inviting': 3954,
#  'friend': 3182,
#  'yes165': 8176,
#  'no165': 5113,
#  'wwwsmsacunatalie2k9': 8112,
#  'frnd': 3190,
#  '62468': 638,
#  'congrats': 2081,
#  '3g': 513,
#  'videophones': 7707,
#  '09063458130': 211,
#  'videochat': 7706,
#  'wid': 7947,
#  'mates': 4670,
#  'java': 4038,
#  'games': 3246,
#  'dload': 2528,
#  'polyph': 5658,
#  'noline': 5136,
#  'rentl': 6072,
#  'bx420': 1670,
#  'ip4': 3961,
#  '5we': 626,
#  'think': 7251,
#  'possibility': 5684,
#  'pub': 5847,
#  '7ish': 688,
#  'valentines': 7666,
#  'lturlgt': 4547,
#  'sleep': 6595,
#  'ltgt': 4544,
#  'useless': 7639,
#  'important': 3854,
#  'decided': 2353,
#  'hungry': 3777,
#  'painful': 5399,
#  'personal': 5513,
#  'thought': 7270,
#  'everybody': 2831,
#  'happy': 3531,
#  'nobody': 5122,
#  'recognises': 6003,
#  'alone': 992,
#  '530': 606,
#  'dunno': 2651,
#  'tickets': 7297,
#  'polyphonic': 5659,
#  'tones': 7379,
#  '087018728737': 74,
#  'national': 5016,
#  'rate': 5939,
#  'toppoly': 7402,
#  'tune': 7496,
#  'week': 7869,
#  'subpoly': 6957,
#  '81618': 712,
#  'pole': 5649,
#  'unsub': 7598,
#  '08718727870': 147,
#  'ron': 6193,
#  'fri': 3177,
#  'leh': 4354,
#  'ding': 2481,
#  'tai': 7085,
#  'feng': 2983,
#  'reservations': 6098,
#  'wait': 7778,
#  'contacted': 2097,
#  'dating': 2308,
#  'someone': 6679,
#  'find': 3021,
#  'land': 4282,
#  '09050000878': 167,
#  'pobox45w2tg150p': 5633,
#  'loan': 4450,
#  'purpose': 5866,
#  '75000': 675,
#  'homeowners': 3690,
#  'tenants': 7167,
#  'previously': 5766,
#  'refused': 6028,
#  '0800': 45,
#  '1956669': 361,
#  'whats': 7917,
#  'sat': 6282,
#  'sooner': 6704,
#  'gary': 3257,
#  'fix': 3049,
#  'cause': 1794,
#  'thinks': 7255,
#  'knows': 4227,
#  'doesnt': 2542,
#  'ptbo': 5845,
#  'cost': 2140,
#  'bucks': 1625,
#  'cheaper': 1856,
#  'second': 6343,
#  'hand': 3507,
#  'machines': 4588,
#  'kkim': 4211,
#  'finewhen': 3027,
#  'complete': 2046,
#  'course': 2161,
#  'hiya': 3652,
#  'paying': 5471,
#  'account': 853,
#  'thanks': 7204,
#  'pleasant': 5604,
#  'surprise': 7032,
#  'checked': 1862,
#  'balance': 1274,
#  'statements': 6853,
#  'acc': 838,
#  'science': 6313,
#  'tells': 7158,
#  'chocolate': 1913,
#  'melt': 4731,
#  'sunlight': 7002,
#  'walk': 7788,
#  'bcozi': 1335,
#  'loss': 4497,
#  'sweet': 7051,
#  'food': 3106,
#  'lei': 4356,
#  'yun': 8229,
#  'wan': 7802,
#  'juz': 4120,
#  'little': 4434,
#  'bit': 1432,
#  'celebrate': 1810,
#  'båõday': 1675,
#  'landline': 4283,
#  'anna': 1045,
#  'nagar': 4994,
#  'afternoon': 922,
#  'could': 2148,
#  'hour': 3729,
#  'stock': 6883,
#  'trip': 7458,
#  'deleted': 2382,
#  'old': 5282,
#  'websitenow': 7862,
#  'blogging': 1462,
#  'magicalsongsblogspotcom': 4607,
#  'waiti': 7779,
#  'min': 4791,
#  'dats': 2310,
#  'told': 7363,
#  'attend': 1190,
#  'drink': 2611,
#  'plenty': 5610,
#  'water': 7833,
#  'short': 6489,
#  'cute': 2258,
#  'care': 1754,
#  'bad': 1263,
#  'break': 1568,
#  'fassyole': 2945,
#  'blacko': 1443,
#  'londn': 4471,
#  'linerental': 4411,
#  'mobiles': 4856,
#  'offers': 5243,
#  'call2optoutlf56': 1698,
#  'cramps': 2179,
#  'stopped': 6897,
#  'lect': 4345,
#  'space': 6734,
#  'invaders': 3947,
#  'orig': 5345,
#  'arcade': 1111,
#  'game': 3245,
#  'console': 2093,
#  'press': 5756,
#  'std': 6861,
#  'wap': 7812,
#  'charge': 1841,
#  'o2coukgames': 5221,
#  'terms': 7174,
#  'settings': 6412,
#  'purchase': 5862,
#  'nan': 5007,
#  'sonathaya': 6695,
#  'soladha': 6672,
#  'boss': 1518,
#  'goodmorning': 3376,
#  '2hrs': 445,
#  'pain': 5398,
#  'throw': 7280,
#  'smoking': 6640,
#  'car': 1749,
#  'history': 3645,
#  'comfort': 2023,
#  'luxury': 4568,
#  'sold': 6673,
#  'onionrs': 5295,
#  'petrolrs': 5527,
#  'beerrs': 1362,
#  'shesil': 6455,
#  'oops': 5311,
#  'haf': 3489,
#  'enuff': 2787,
#  'awarded': 1233,
#  '1500': 313,
#  'bonus': 1498,
#  'caller': 1706,
#  'prize': 5784,
#  '27603': 424,
#  'final': 3016,
#  'attempt': 1188,
#  'contact': 2096,
#  '08714714011': 115,
#  'longer': 4476,
#  'pisces': 5573,
#  'aquarius': 1108,
#  'worry': 8047,
#  'lambu': 4279,
#  'ji': 4064,
#  'vl': 7740,
#  'cometil': 2022,
#  'batchlor': 1312,
#  'party': 5445,
#  'anytime': 1073,
#  'comin': 2024,
#  'wanted': 7809,
#  'finishes': 3032,
#  'anyway': 1074,
#  'tuition': 7492,
#  'empty': 2747,
#  'slots': 6612,
#  'driving': 2618,
#  '09064017305': 216,
#  'pobox75ldns7': 5634,
#  'moan': 4853,
#  'finally': 3018,
#  'came': 1722,
#  'ceiling': 1807,
#  'thts': 7288,
#  'wright': 8065,
#  'brother': 1606,
#  'fly': 3086,
#  'ambrithmaduraimet': 1011,
#  'arun': 1148,
#  'dha': 2438,
#  'marrgeremembr': 4654,
#  '02070836089': 9,
#  'tessypls': 7181,
#  'favor': 2960,
#  'convey': 2113,
#  'birthday': 1430,
#  'wishes': 7981,
#  'nimyapls': 5100,
#  'dnt': 2529,
#  'forget': 3119,
#  'shijas': 6457,
#  'bahamas': 1268,
#  'callfreefone': 1709,
#  '08081560665': 59,
#  'operator': 5318,
#  'either': 2716,
#  'cruise': 2214,
#  'ofå': 5258,
#  '2000': 385,
#  '18only': 358,
#  'opt': 5326,
#  '07786200117': 31,
#  'usual': 7649,
#  'patty': 5463,
#  'donewant': 2564,
#  'smoke': 6637,
#  'haul': 3547,
#  'ass': 1167,
#  'bec': 1347,
#  'temple': 7165,
#  'na': 4990,
#  'al': 967,
#  'thin': 7247,
#  'goes': 3352,
#  'wrong': 8074,
#  'faultal': 2956,
#  'de': 2329,
#  'arguments': 1123,
#  'faultfed': 2957,
#  'himso': 3639,
#  'bother': 1521,
#  'hav': 3549,
#  '2go': 442,
#  'thanxxx': 7209,
#  '200': 384,
#  'spree': 6799,
#  '08717895698': 134,
#  'mobstorequiz10ppm': 4863,
#  'quite': 5899,
#  'lar': 4294,
#  'ard': 1112,
#  'wun': 8083,
#  'drivin': 2617,
#  'xy': 8146,
#  'special': 6748,
#  'thanx': 7208,
#  'tau': 7117,
#  'sar': 6274,
#  'piah': 5550,
#  'understand': 7564,
#  'gain': 3236,
#  'work': 8032,
#  'school': 6311,
#  'knowwait': 4229,
#  'booked': 1502,
#  'pilates': 5567,
#  'yoga': 8200,
#  'lesson': 4366,
#  'information': 3899,
#  'loving': 4525,
#  'arpraveesh': 1135,
#  'details': 2426,
#  'log': 4459,
#  'face': 2906,
#  'book': 1501,
#  'delicious': 2384,
#  'treat': 7449,
#  'entry': 2785,
#  'weekly': 7873,
#  'comp': 2033,
#  '80086': 700,
#  '18': 353,
#  'tc': 7127,
#  'wwwtxttowincouk': 8121,
#  'tas': 7111,
#  'earn': 2668,
#  'busy': 1656,
#  'hee': 3580,
#  'seeing': 6357,
#  'gr8': 3404,
#  'morning': 4903,
#  'wish': 7979,
#  'full': 3215,
#  'feeling': 2975,
#  'better': 1398,
#  'opportunity': 5322,
#  'forward': 3137,
#  'sex': 6418,
#  'cuddling': 2234,
#  'sleeps': 6600,
#  'funk': 3223,
#  'tone': 7378,
#  'tones2u': 7380,
#  'wwwringtonescouk': 8105,
#  'original': 5346,
#  'best': 1392,
#  '3gbp': 514,
#  'rates': 5940,
#  'open': 5312,
#  'idea': 3815,
#  'jay': 4039,
#  'hell': 3586,
#  'put': 5872,
#  'jus': 4116,
#  'lido': 4380,
#  '930': 796,
#  'tonight': 7384,
#  'somethings': 6686,
#  'id': 3813,
#  'velachery': 7686,
#  'sexy': 6421,
#  'singles': 6552,
#  'age': 928,
#  'followed': 3098,
#  'gender': 3282,
#  'wither': 7987,
#  'eg23f': 2702,
#  'gay': 3263,
#  'eg23g': 2703,
#  'oic': 5265,
#  'sis': 6562,
#  'dad': 2273,
#  'went': 7896,
#  'whether': 7932,
#  'sch': 6309,
#  'santa': 6272,
#  'ones': 5292,
#  'eve': 2820,
#  '09077818151': 243,
#  'calls150ppm': 1715,
#  '3mins': 518,
#  '30s': 482,
#  'wwwsantacallingcom': 8106,
#  'film': 3012,
#  'part': 5437,
#  'survey': 7036,
#  'however': 3740,
#  '80160': 702,
#  'wwwtxt43com': 8119,
#  'weightloss': 7880,
#  'girl': 3316,
#  'loads': 4449,
#  'ebay': 2683,
#  'give': 3322,
#  'licks': 4379,
#  'center': 1815,
#  'tootsie': 7396,
#  'pop': 5671,
#  'slowly': 6616,
#  'godi': 3348,
#  'youclean': 8205,
#  'heart': 3569,
#  'bloodsend': 1469,
#  'miracle': 4811,
#  'itplspls': 4001,
#  'jacket': 4019,
#  'ah': 941,
#  '8th': 791,
#  'fifty': 2998,
#  'radio': 5910,
#  '2stoptxt': 464,
#  'tcs': 7130,
#  'yan': 8153,
#  'jiu': 4068,
#  'liao': 4373,
#  'bugis': 1634,
#  'vill': 7718,
#  'frm': 3189,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8263 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
print(X_train_vect.shape)
print(len(y_train))
print(y_train)
# Out:
# (4457, 8263)
# 4457
#       label
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 4452      0
# 4453      1
# 4454      0
# 4455      0
# 4456      0
#
# [4457 rows x 1 columns]

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=10)
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)
print(y_pred)
# Out:
# [0 0 0 ... 0 0 1]

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 0.967 / Recall: 0.783 / Accuracy: 0.967
